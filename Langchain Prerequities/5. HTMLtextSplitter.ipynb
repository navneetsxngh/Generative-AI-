# %% [markdown]
# ## How to split by **HTML Header**

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
html_string = """
<!DOCTYPE html>
<html>
<body>

<h1>AI Agents</h1>
<p>AI agents are systems that act autonomously.</p>

<h2>Types</h2>
<p>There are multiple types of agents.</p>

<h3>Reactive</h3>
<p>No memory, immediate response.</p>

<h3>Deliberative</h3>
<p>Uses planning and reasoning.</p>

<h2>Applications</h2>
<p>Used in chatbots and robotics.</p>

</body>
</html>
"""

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3")
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits=html_splitter.split_text(html_string)
html_header_splits
# Out:
# [Document(metadata={'Header 1': 'AI Agents'}, page_content='AI Agents'),
#  Document(metadata={'Header 1': 'AI Agents'}, page_content='AI agents are systems that act autonomously.'),
#  Document(metadata={'Header 1': 'AI Agents', 'Header 2': 'Types'}, page_content='Types'),
#  Document(metadata={'Header 1': 'AI Agents', 'Header 2': 'Types'}, page_content='There are multiple types of agents.'),
#  Document(metadata={'Header 1': 'AI Agents', 'Header 2': 'Types', 'Header 3': 'Reactive'}, page_content='Reactive'),
#  Document(metadata={'Header 1': 'AI Agents', 'Header 2': 'Types', 'Header 3': 'Reactive'}, page_content='No memory, immediate response.'),
#  Document(metadata={'Header 1': 'AI Agents', 'Header 2': 'Types', 'Header 3': 'Deliberative'}, page_content='Deliberative'),
#  Document(metadata={'Header 1': 'AI Agents', 'Header 2': 'Types', 'Header 3': 'Deliberative'}, page_content='Uses planning and reasoning.'),
# ...

# %%
url = "https://plato.stanford.edu/entries/goedel/"

headers_to_split_on= [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
    ("h4", "Header 4")
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits = html_splitter.split_text_from_url(url)
html_header_splits[0]
# Out:
# Document(metadata={}, page_content='End container NOTE: Script required for drop-down button to work (mirrors).  \nEnd header wrapper End content End footer  \nEnd header  \nEnd navigation End search  \nStanford Encyclopedia of Philosophy  \nMenu  \nBrowse  \nTable of Contents  \nWhat\'s New  \nRandom Entry  \nChronological  \nArchives  \nAbout  \nEditorial Information  \nAbout the SEP  \nEditorial Board  \nHow to Cite the SEP  \nSpecial Characters  \nAdvanced Tools  \nContact  \nSupport SEP  \nSupport the SEP  \nPDFs for SEP Friends  \nMake a Donation  \nSEPIA for Libraries  \nBegin article sidebar End article sidebar NOTE: Article content must have two wrapper divs: id="article" and id="article-content" End article NOTE: article banner is outside of the id="article" div. End article-banner  \nEntry Navigation  \nEntry Contents  \nBibliography  \nAcademic Tools  \nFriends PDF Preview  \nAuthor and Citation Info  \nBack to Top  \nEnd article-content  \nBEGIN ARTICLE HTML #aueditable 
# ...
